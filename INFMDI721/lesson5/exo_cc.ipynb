# %% [markdown]
# En repartant du dataset "people.csv" (cf. lesson4) dans sa version "clean" finale:
#
# - mettre la colonne `inactive` à `true` pour tous les users dont le `last_seen` date d'au moins un an
# - avec une regex: filtrer les numéros de téléphone invalides
# - ajouter une colonne indiquant si le numéro de tel correspond à un téléphone portable (06/07)
# - ajouter une colonne indiquant si les coordonnées GPS de l'utilisateur correspondent bien au "country"

# %%
import pandas as pd

# if you don't want pandas.read_csv to mess with data types,
# you can force it to keep str values by specifying dtype=str.
people = pd.read_csv('people.csv')

# %%
def clean_people(df):
    # rename columns:
    df = df.rename(columns={'email address': 'email'})
    
    # remove rows which have an empty "first_name" (NA):
    #df = df[df.first_name.notna()] <- equivalent to next line:
    df = df.dropna(subset=['first_name'])
    
    # drop duplicates on ID column:
    df = df.drop_duplicates()
    
    # Normalize gender column:
    df['gender'] = df['gender'].replace({'Female': 'F', 'Male': 'M'})
    
    # Convert column "age" to number (coerce: put NaN for bad values):
    df['age'] = pd.to_numeric(df.age, errors='coerce')
    
    # Convert columns to date type:
    df['registration'] = pd.to_datetime(df.registration)
    df['last_seen'] = pd.to_datetime(df.last_seen, unit='s')
    # When missing, last seen should fallback to the registration date:
    df['last_seen'] = df.last_seen.combine_first(df.registration)
    
    # Add a "full_name" column by concatenating two other ones:
    df['full_name'] = df.first_name + " " + df.last_name
    
    # Add a "country" column by extracting it from the address, with a split:
    df['country'] = df.address.str.split(', ').str[1]
    
    # Column "money" contains values like "$50.23" or "€23,09".
    # We want to make it uniform (only dollar currency) and as number, not str.
    df['currency'] = df.money.str[0]  # extract first char ($/€) to a new "currency" column
    df['money'] = df.money.str[1:].str.replace(',', '.')  # extract remaining chars and replace , by .
    df['money'] = pd.to_numeric(df.money)  # convert to number
    # convert euros cells to dollar:
    df.loc[df.currency == '€', 'money'] = df[df.currency == '€'].money * 1.10
    del df['currency']  # remove "currency" column which is now useless
    
    # Keep only rows where email is not NA:
    df = df.dropna(subset=['email'])
    # Keep only rows where email is a good email:
    # CAUTION: in the real world you should not use dummy regexes like this to validate email addresses,
    # but instead use a dedicated tool like https://github.com/syrusakbary/validate_email.
    df = df[df.email.str.contains('.+@[0-9a-zA-Z\.\-_]+\.\w{2,}')]
    # Some users may use email alias (example: john.smith+truc@gmail.com is an alias for john.smith@gmail.com).
    # We want to drop these duplicates. To do that, we extract the 'alias' part with a regex:
    groups = df.email.str.extract('([0-9a-zA-Z\.\-_]+)(\+[0-9a-zA-Z\.\-_]+)?(@[0-9a-zA-Z\.\-_]+\.\w{2,})')
    df['email'] = groups[0] + groups[2]  # we override the email with the email without the alias part
    # Then, just use drop_duplicates, which will keep the first line by default:
    df = df.drop_duplicates(subset=['email'])
    
    return df

df_clean = clean_people(people)

# %%
df_clean.head()
# Out:
#       id first_name  last_name                         email gender   age  \
# 0  27625    Leandra    Pabelik           lpabelik5f@yale.edu      F  63.0
# 1  27570      Ruthi       Ross              rross3w@sohu.com      F  57.0
# 2  27572      Silas   Stourton  silas.stourton3y@answers.com      M  22.0
# 3  27435     Roxine  Pettecrew      rpettecrew5@gravatar.com      F  64.0
# 5  27497     Gordie    Bodicum         gbodicum1v@apache.org      M  60.0
#
#      money         lon        lat       phone registration inactive  \
# 0   55.180   18.284100  49.632552  0136319724   2019-04-16    False
# 1   20.370   19.230220  50.466575         NaN   2018-10-23    False
# 2   36.289  118.831081  24.984813         NaN   2018-12-30    False
# 3  108.823  121.648987  -8.844744         NaN   2019-03-12    False
# 5   47.260   13.978681  49.786243  0146943857   2017-04-29    False
#
#             last_seen                    address           preference  \
# 0 2019-06-03 12:39:57  Palkovice, Czech Republic  entrée/plat/dessert
# 1 2019-08-30 11:41:04           Siewierz, Poland  entrée/plat/dessert
# 2 2019-03-27 13:10:32              Longbo, China  entrée/plat/dessert
# 3 2019-03-12 00:00:00       Potulando, Indonesia          entrée/plat
# 5 2018-12-26 07:40:36      Jince, Czech Republic  entrée/plat/dessert
#
#           full_name         country
# 0   Leandra Pabelik  Czech Republic
# 1        Ruthi Ross          Poland
# 2    Silas Stourton           China
# 3  Roxine Pettecrew       Indonesia
# 5    Gordie Bodicum  Czech Republic

# %%
import datetime

test = df.copy()

is_inactive = df_clean.last_seen < datetime.datetime.now() \
    .replace(year=stop_date.year-1)

is_inactive = df_clean.last_seen < \
    (datetime.datetime.now() - datetime.timedelta(days=365))
test['inactive'] = is_inactive

test.head(20)
# Out:
#        id first_name    last_name                             email gender  \
# 0   27625    Leandra      Pabelik               lpabelik5f@yale.edu      F
# 1   27570      Ruthi         Ross                  rross3w@sohu.com      F
# 2   27572      Silas     Stourton      silas.stourton3y@answers.com      M
# 3   27435     Roxine    Pettecrew          rpettecrew5@gravatar.com      F
# 5   27497     Gordie      Bodicum             gbodicum1v@apache.org      M
# 6   27539    Dulcine    Stopforth           dstopforth31@forbes.com      F
# 7   27469      Denny       Hasnip            dhasnip13@so-net.ne.jp      F
# 9   27565  Esmeralda   Hollindale      ehollindale3r@guardian.co.uk      F
# 10  27446    Skippie       Arlott             sarlottg@so-net.ne.jp      M
# 11  27550    Shermie       Locard               slocard3c@lycos.com      M
# 12  27548    Stanley     McCullen     smccullen3a@timesonline.co.uk      M
# 13  27537       Lila   Yellowlees          lyellowlees2z@cdbaby.com      F
# 14  27554         Ty       Havock            thavock3g@google.co.jp      M
# 15  27619    Shelley      Skeemor          sskeemor59@princeton.edu      F
# 16  27442       Mort      Midford                mmidfordc@yale.edu      M
# 17  27602     Eimile  Staterfield        estaterfield4s@cbsnews.com      F
# 18  27513   Dominick   Hryncewicz       dhryncewicz2b@amazonaws.com      M
# 19  27507       Tate     Feldmann  tfeldmann25@networksolutions.com      M
# 20  27462      Graig     Brownsea        gbrownseaw@arstechnica.com      M
# 21  27466      Baron     Spurrett               bspurrett10@psu.edu      M
#
#      age    money         lon        lat       phone registration  inactive  \
# 0   63.0   55.180   18.284100  49.632552  0136319724   2019-04-16     False
# 1   57.0   20.370   19.230220  50.466575         NaN   2018-10-23     False
# 2   22.0   36.289  118.831081  24.984813         NaN   2018-12-30     False
# 3   64.0  108.823  121.648987  -8.844744         NaN   2019-03-12     False
# 5   60.0   47.260   13.978681  49.786243  0146943857   2017-04-29     False
# 6   22.0   13.860  -35.587670  -6.255393         NaN   2017-12-13     False
# 7   47.0   83.567  -89.917591  14.113818         NaN   2017-05-01     False
# 9   29.0   60.590  -36.508738 -54.281149         NaN   2017-10-05      True
# 10  49.0   27.797   38.954230  55.877840         NaN   2017-08-13      True
# 11  65.0   35.948  112.813530  -7.305958         NaN   2018-09-29     False
# 12  60.0      NaN  119.141473  28.074649  0875503094   2017-06-05      True
# 13  70.0   52.800  -51.528917 -29.258165         NaN   2017-05-26     False
# 14  55.0   36.003  112.044491  22.915094         NaN   2017-02-08     False
# 15  44.0   41.500  111.878471  -7.584917  0547556034   2019-01-24     False
# 16  59.0      NaN    6.848501   5.959253  0811321968   2019-06-25     False
# 17  67.0   38.510  -78.845814  -2.738998         NaN   2017-12-10     False
# 18  56.0   80.710   68.214686  38.530112         NaN   2017-08-04     False
# 19   NaN   92.169   30.156044 -23.411495         NaN   2017-06-06      True
# 20  54.0   80.230  110.393439  -7.213328  0262855559   2018-05-22     False
# 21  36.0   57.560   16.580506 -18.360404  06etcetera   2018-07-20     False
#
#              last_seen                     address           preference  \
# 0  2019-06-03 12:39:57   Palkovice, Czech Republic  entrée/plat/dessert
# 1  2019-08-30 11:41:04            Siewierz, Poland  entrée/plat/dessert
# 2  2019-03-27 13:10:32               Longbo, China  entrée/plat/dessert
# 3  2019-03-12 00:00:00        Potulando, Indonesia          entrée/plat
# 5  2018-12-26 07:40:36       Jince, Czech Republic  entrée/plat/dessert
# 6  2019-01-15 15:39:05            Serrinha, Brazil  entrée/plat/dessert
# 7  2019-03-08 18:46:46           Comapa, Guatemala  entrée/plat/dessert
# 9  2018-04-12 15:45:51            Grytviken, China  entrée/plat/dessert
# 10 2018-10-06 10:55:59        Malaya Dubna, Russia  entrée/plat/dessert
# 11 2019-05-03 00:23:45         Wonorejo, Indonesia  entrée/plat/dessert
# 12 2017-06-05 00:00:00             Longquan, China  entrée/plat/dessert
# 13 2019-06-08 15:55:33           Garibaldi, Brazil  entrée/plat/dessert
# 14 2019-09-29 06:27:12                Yunfu, China  entrée/plat/dessert
# 15 2019-05-04 13:18:24         Guyangan, Indonesia  entrée/plat/dessert
# 16 2019-06-25 00:00:00            Ozubulu, Nigeria          entrée/plat
# 17 2019-06-27 23:11:25            Azogues, Ecuador  entrée/plat/dessert
# 18 2019-07-26 02:33:01      Tursunzoda, Tajikistan  entrée/plat/dessert
# 19 2018-04-27 17:45:14  Duiwelskloof, South Africa  entrée/plat/dessert
# 20 2019-09-28 13:28:10        Sidomukti, Indonesia  entrée/plat/dessert
# 21 2019-02-02 18:29:51           Omuthiya, Namibia  entrée/plat/dessert
#
#                full_name         country
# 0        Leandra Pabelik  Czech Republic
# 1             Ruthi Ross          Poland
# 2         Silas Stourton           China
# 3       Roxine Pettecrew       Indonesia
# 5         Gordie Bodicum  Czech Republic
# 6      Dulcine Stopforth          Brazil
# 7           Denny Hasnip       Guatemala
# 9   Esmeralda Hollindale           China
# 10        Skippie Arlott          Russia
# 11        Shermie Locard       Indonesia
# 12      Stanley McCullen           China
# 13       Lila Yellowlees          Brazil
# 14             Ty Havock           China
# 15       Shelley Skeemor       Indonesia
# 16          Mort Midford         Nigeria
# 17    Eimile Staterfield         Ecuador
# 18   Dominick Hryncewicz      Tajikistan
# 19         Tate Feldmann    South Africa
# 20        Graig Brownsea       Indonesia
# 21        Baron Spurrett         Namibia

# %%
import re
pattern = '?:\B\+ ?49|\b0)(?: *[(-]? *\d(?:[ \d]*\d)?)? *(?:[)-] *)?\d+ *(?:[/)-] *)?\d+ *(?:[/)-] *)?\d+(?: *- *\d+)?'

pattern = '^0\d{9}$'
df_clean.phone.str.contains(pattern, regex=True)
# Out:
# 0      True
# 1       NaN
# 2       NaN
# 3       NaN
# 5      True
#        ...
# 204     NaN
# 205     NaN
# 206    True
# 207    True
# 208    True
# Name: phone, Length: 191, dtype: object
