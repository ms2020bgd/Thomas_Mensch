# %% [markdown]
# En repartant du dataset "people.csv" (cf. lesson4) dans sa version "clean" finale:
#
#  1. mettre la colonne `inactive` à `true` pour tous les users dont le `last_seen` date d'au moins un an
#  2. avec une regex: filtrer les numéros de téléphone invalides
#  3. ajouter une colonne indiquant si le numéro de tel correspond à un téléphone portable (06/07)
#  4. ajouter une colonne indiquant si les coordonnées GPS de l'utilisateur correspondent bien au "country"

# %%
import datetime
import pandas as pd
import re
import requests

# %%
# if you don't want pandas.read_csv to mess with data types,
# you can force it to keep str values by specifying dtype=str.
df = pd.read_csv('people.csv')

# %%
def clean_people(df):
    # rename columns:
    df = df.rename(columns={'email address': 'email'})
    
    # remove rows which have an empty "first_name" (NA):
    #df = df[df.first_name.notna()] <- equivalent to next line:
    df = df.dropna(subset=['first_name'])
    
    # drop duplicates on ID column:
    df = df.drop_duplicates()
    
    # Normalize gender column:
    df['gender'] = df['gender'].replace({'Female': 'F', 'Male': 'M'})
    
    # Convert column "age" to number (coerce: put NaN for bad values):
    df['age'] = pd.to_numeric(df.age, errors='coerce')
    
    # Convert columns to date type:
    df['registration'] = pd.to_datetime(df.registration)
    df['last_seen'] = pd.to_datetime(df.last_seen, unit='s')
    # When missing, last seen should fallback to the registration date:
    df['last_seen'] = df.last_seen.combine_first(df.registration)
    
    # Add a "full_name" column by concatenating two other ones:
    df['full_name'] = df.first_name + " " + df.last_name
    
    # Add a "country" column by extracting it from the address, with a split:
    df['country'] = df.address.str.split(', ').str[1]
    
    # Column "money" contains values like "$50.23" or "€23,09".
    # We want to make it uniform (only dollar currency) and as number, not str.
    df['currency'] = df.money.str[0]  # extract first char ($/€) to a new "currency" column
    df['money'] = df.money.str[1:].str.replace(',', '.')  # extract remaining chars and replace , by .
    df['money'] = pd.to_numeric(df.money)  # convert to number
    # convert euros cells to dollar:
    df.loc[df.currency == '€', 'money'] = df[df.currency == '€'].money * 1.10
    del df['currency']  # remove "currency" column which is now useless
    
    # Keep only rows where email is not NA:
    df = df.dropna(subset=['email'])
    # Keep only rows where email is a good email:
    # CAUTION: in the real world you should not use dummy regexes like this to validate email addresses,
    # but instead use a dedicated tool like https://github.com/syrusakbary/validate_email.
    df = df[df.email.str.contains('.+@[0-9a-zA-Z\.\-_]+\.\w{2,}')]
    # Some users may use email alias (example: john.smith+truc@gmail.com is an alias for john.smith@gmail.com).
    # We want to drop these duplicates. To do that, we extract the 'alias' part with a regex:
    groups = df.email.str.extract('([0-9a-zA-Z\.\-_]+)(\+[0-9a-zA-Z\.\-_]+)?(@[0-9a-zA-Z\.\-_]+\.\w{2,})')
    df['email'] = groups[0] + groups[2]  # we override the email with the email without the alias part
    # Then, just use drop_duplicates, which will keep the first line by default:
    df = df.drop_duplicates(subset=['email'])
    
    return df

df = clean_people(df)

# %%
df.head()
# Out:
#       id first_name  last_name                         email gender   age  \
# 0  27625    Leandra    Pabelik           lpabelik5f@yale.edu      F  63.0
# 1  27570      Ruthi       Ross              rross3w@sohu.com      F  57.0
# 2  27572      Silas   Stourton  silas.stourton3y@answers.com      M  22.0
# 3  27435     Roxine  Pettecrew      rpettecrew5@gravatar.com      F  64.0
# 5  27497     Gordie    Bodicum         gbodicum1v@apache.org      M  60.0
#
#      money         lon        lat       phone registration inactive  \
# 0   55.180   18.284100  49.632552  0136319724   2019-04-16    False
# 1   20.370   19.230220  50.466575         NaN   2018-10-23    False
# 2   36.289  118.831081  24.984813         NaN   2018-12-30    False
# 3  108.823  121.648987  -8.844744         NaN   2019-03-12    False
# 5   47.260   13.978681  49.786243  0146943857   2017-04-29    False
#
#             last_seen                    address           preference  \
# 0 2019-06-03 12:39:57  Palkovice, Czech Republic  entrée/plat/dessert
# 1 2019-08-30 11:41:04           Siewierz, Poland  entrée/plat/dessert
# 2 2019-03-27 13:10:32              Longbo, China  entrée/plat/dessert
# 3 2019-03-12 00:00:00       Potulando, Indonesia          entrée/plat
# 5 2018-12-26 07:40:36      Jince, Czech Republic  entrée/plat/dessert
#
#           full_name         country
# 0   Leandra Pabelik  Czech Republic
# 1        Ruthi Ross          Poland
# 2    Silas Stourton           China
# 3  Roxine Pettecrew       Indonesia
# 5    Gordie Bodicum  Czech Republic

# %% [markdown]
# ### 1. Mettre la colonne `inactive` à true pour tous les users dont le last_seen date d'au moins un an

# %%
# set inactive people
date_threshold = datetime.datetime.now() - datetime.timedelta(days=365)
df['inactive'] = df.last_seen < date_threshold

df.head()
# Out:
#       id first_name  last_name                         email gender   age  \
# 0  27625    Leandra    Pabelik           lpabelik5f@yale.edu      F  63.0
# 1  27570      Ruthi       Ross              rross3w@sohu.com      F  57.0
# 2  27572      Silas   Stourton  silas.stourton3y@answers.com      M  22.0
# 3  27435     Roxine  Pettecrew      rpettecrew5@gravatar.com      F  64.0
# 5  27497     Gordie    Bodicum         gbodicum1v@apache.org      M  60.0
#
#      money         lon        lat       phone registration  inactive  \
# 0   55.180   18.284100  49.632552  0136319724   2019-04-16     False
# 1   20.370   19.230220  50.466575         NaN   2018-10-23     False
# 2   36.289  118.831081  24.984813         NaN   2018-12-30     False
# 3  108.823  121.648987  -8.844744         NaN   2019-03-12     False
# 5   47.260   13.978681  49.786243  0146943857   2017-04-29     False
#
#             last_seen                    address           preference  \
# 0 2019-06-03 12:39:57  Palkovice, Czech Republic  entrée/plat/dessert
# 1 2019-08-30 11:41:04           Siewierz, Poland  entrée/plat/dessert
# 2 2019-03-27 13:10:32              Longbo, China  entrée/plat/dessert
# 3 2019-03-12 00:00:00       Potulando, Indonesia          entrée/plat
# 5 2018-12-26 07:40:36      Jince, Czech Republic  entrée/plat/dessert
#
#           full_name         country
# 0   Leandra Pabelik  Czech Republic
# 1        Ruthi Ross          Poland
# 2    Silas Stourton           China
# 3  Roxine Pettecrew       Indonesia
# 5    Gordie Bodicum  Czech Republic

# %% [markdown]
# ### 2. avec une regex: filtrer les numéros de téléphone invalides

# %%
# filter valid phone number
pattern = '^0\d{9}$'

df = df[df.phone.str.contains(pattern, regex=True) == True]

df.head(20)
# Out:
#        id first_name   last_name                          email gender   age  \
# 0   27625    Leandra     Pabelik            lpabelik5f@yale.edu      F  63.0
# 5   27497     Gordie     Bodicum          gbodicum1v@apache.org      M  60.0
# 12  27548    Stanley    McCullen  smccullen3a@timesonline.co.uk      M  60.0
# 15  27619    Shelley     Skeemor       sskeemor59@princeton.edu      F  44.0
# 16  27442       Mort     Midford             mmidfordc@yale.edu      M  59.0
# 20  27462      Graig    Brownsea     gbrownseaw@arstechnica.com      M  54.0
# 24  27563      Andre     Lugsdin       alugsdin3p@microsoft.com      M  30.0
# 27  27551      Brigg      Bryett            bbryett3d@prlog.org      M  20.0
# 30  27440      Erick     Meharry       emeharrya@wikispaces.com      M  52.0
# 31  27593     Evelyn   Olenichev   eolenichev4j@tripadvisor.com      F  44.0
# 33  27463     Caesar  Ferrarotti            cferrarottix@qq.com      M  59.0
# 38  27494       Gill     Cottell           gcottell1s@upenn.edu      F  63.0
# 40  27566     Amalie  Matthisson          aMatthisson3s@ted.com      F  63.0
# 45  27432   Gardener     Kempson             gkempson2@furl.net      M  33.0
# 49  27458    Osborne        Donn           odonns@webeden.co.uk      M  33.0
# 51  27445   Gardener       Brosi             gbrosif@flickr.com      M  47.0
# 53  27467     Worden     Shewery         wshewery11@smugmug.com      M  26.0
# 56  27471    Grethel    Burnyate            gburnyate15@mail.ru      F  43.0
# 57  27547     Vasily     Moggach                vmoggach39@g.co      M  39.0
# 61  27543      Ogden       Jertz         ojertz35@aboutads.info      M  20.0
#
#      money         lon        lat       phone registration  inactive  \
# 0   55.180   18.284100  49.632552  0136319724   2019-04-16     False
# 5   47.260   13.978681  49.786243  0146943857   2017-04-29     False
# 12     NaN  119.141473  28.074649  0875503094   2017-06-05      True
# 15  41.500  111.878471  -7.584917  0547556034   2019-01-24     False
# 16     NaN    6.848501   5.959253  0811321968   2019-06-25     False
# 20  80.230  110.393439  -7.213328  0262855559   2018-05-22     False
# 24  40.630   12.219712  57.121813  0144026028   2017-01-15     False
# 27  28.050  102.638296  24.301245  0746863267   2017-10-25     False
# 30  44.792    3.575175  47.794456  0098166909   2017-04-21      True
# 31  54.252   23.711756  37.944288  0214068650   2017-01-02     False
# 33  66.924  112.867154  -6.921845  0346857462   2018-12-10     False
# 38  64.130    0.813275  46.647310  0177869521   2017-01-09     False
# 40  15.279   16.304150  57.993607  0409272683   2019-01-20     False
# 45  41.300   25.911060  49.103782  0774378059   2017-09-08     False
# 49  37.609  117.430061  23.701262  0721208335   2018-09-01     False
# 51  39.182  -39.071075 -11.256817  0321573819   2017-03-30     False
# 53  15.670   19.883333  40.916667  0517301167   2018-08-22     False
# 56  39.990  106.617342  -6.295621  0593299765   2017-01-19      True
# 57  51.711   20.254048  50.748099  0133026726   2018-01-07      True
# 61     NaN   15.559672  46.073321  0228944761   2017-07-10      True
#
#              last_seen                    address           preference  \
# 0  2019-06-03 12:39:57  Palkovice, Czech Republic  entrée/plat/dessert
# 5  2018-12-26 07:40:36      Jince, Czech Republic  entrée/plat/dessert
# 12 2017-06-05 00:00:00            Longquan, China  entrée/plat/dessert
# 15 2019-05-04 13:18:24        Guyangan, Indonesia  entrée/plat/dessert
# 16 2019-06-25 00:00:00           Ozubulu, Nigeria          entrée/plat
# 20 2019-09-28 13:28:10       Sidomukti, Indonesia  entrée/plat/dessert
# 24 2019-06-03 02:11:38            Varberg, Sweden  entrée/plat/dessert
# 27 2019-04-10 01:46:26           Dayingjie, China  entrée/plat/dessert
# 30 2018-07-11 08:22:11            Auxerre, France  entrée/plat/dessert
# 31 2019-08-07 22:59:39         Néa Smýrni, Greece  entrée/plat/dessert
# 33 2019-10-02 02:43:57    Trogan Barat, Indonesia  entrée/plat/dessert
# 38 2018-11-03 14:49:10            Ajaccio, France  entrée/plat/dessert
# 40 2019-01-20 00:00:00          Linköping, Sweden  entrée/plat/dessert
# 45 2019-03-18 18:58:59       Kopychyntsi, Ukraine  entrée/plat/dessert
# 49 2019-03-07 22:09:24             Dongshe, China         plat/dessert
# 51 2019-05-11 01:15:13              Araci, Brazil  entrée/plat/dessert
# 53 2018-11-22 07:43:27             Kajan, Albania  entrée/plat/dessert
# 56 2018-10-03 08:57:02      Pagedangan, Indonesia  entrée/plat/dessert
# 57 2018-10-07 01:15:33           Złotniki, Poland  entrée/plat/dessert
# 61 2017-07-10 00:00:00            Kozje, Slovenia  entrée/plat/dessert
#
#             full_name         country
# 0     Leandra Pabelik  Czech Republic
# 5      Gordie Bodicum  Czech Republic
# 12   Stanley McCullen           China
# 15    Shelley Skeemor       Indonesia
# 16       Mort Midford         Nigeria
# 20     Graig Brownsea       Indonesia
# 24      Andre Lugsdin          Sweden
# 27       Brigg Bryett           China
# 30      Erick Meharry          France
# 31   Evelyn Olenichev          Greece
# 33  Caesar Ferrarotti       Indonesia
# 38       Gill Cottell          France
# 40  Amalie Matthisson          Sweden
# 45   Gardener Kempson         Ukraine
# 49       Osborne Donn           China
# 51     Gardener Brosi          Brazil
# 53     Worden Shewery         Albania
# 56   Grethel Burnyate       Indonesia
# 57     Vasily Moggach          Poland
# 61        Ogden Jertz        Slovenia

# %% [markdown]
# ### 3. Ajouter une colonne indiquant si le numéro de tel correspond à un téléphone portable (06/07)

# %%
df['is_mobile'] = df.phone.str.contains('^06|^07')

df.head()
# Out:
#        id first_name last_name                          email gender   age  \
# 0   27625    Leandra   Pabelik            lpabelik5f@yale.edu      F  63.0
# 5   27497     Gordie   Bodicum          gbodicum1v@apache.org      M  60.0
# 12  27548    Stanley  McCullen  smccullen3a@timesonline.co.uk      M  60.0
# 15  27619    Shelley   Skeemor       sskeemor59@princeton.edu      F  44.0
# 16  27442       Mort   Midford             mmidfordc@yale.edu      M  59.0
#
#     money         lon        lat       phone registration  inactive  \
# 0   55.18   18.284100  49.632552  0136319724   2019-04-16     False
# 5   47.26   13.978681  49.786243  0146943857   2017-04-29     False
# 12    NaN  119.141473  28.074649  0875503094   2017-06-05      True
# 15  41.50  111.878471  -7.584917  0547556034   2019-01-24     False
# 16    NaN    6.848501   5.959253  0811321968   2019-06-25     False
#
#              last_seen                    address           preference  \
# 0  2019-06-03 12:39:57  Palkovice, Czech Republic  entrée/plat/dessert
# 5  2018-12-26 07:40:36      Jince, Czech Republic  entrée/plat/dessert
# 12 2017-06-05 00:00:00            Longquan, China  entrée/plat/dessert
# 15 2019-05-04 13:18:24        Guyangan, Indonesia  entrée/plat/dessert
# 16 2019-06-25 00:00:00           Ozubulu, Nigeria          entrée/plat
#
#            full_name         country  is_mobile
# 0    Leandra Pabelik  Czech Republic      False
# 5     Gordie Bodicum  Czech Republic      False
# 12  Stanley McCullen           China      False
# 15   Shelley Skeemor       Indonesia      False
# 16      Mort Midford         Nigeria      False

# %% [markdown]
# ### 4. Ajouter une colonne indiquant si les coordonnées GPS de l'utilisateur correspondent bien au "country"

# %%
# country of IP address

def getCountryFromLonLat(x):

    result = None
    query = "https://geocode.xyz/{:.4f},{:.4f}?json=1".format(x[0], x[1])
    
    json = requests.get(query).json()

    if 'country' in json:
        result = json['country']

    return result


df["countryGuess"] = df[['lon','lat']].apply(getCountryFromLonLat, axis=1)

df.head()
# Out:
# https://geocode.xyz/18.2841,49.6326?json=1
# https://geocode.xyz/13.9787,49.7862?json=1
# https://geocode.xyz/119.1415,28.0746?json=1
# https://geocode.xyz/111.8785,-7.5849?json=1
# https://geocode.xyz/6.8485,5.9593?json=1
# https://geocode.xyz/110.3934,-7.2133?json=1
# https://geocode.xyz/12.2197,57.1218?json=1
# https://geocode.xyz/102.6383,24.3012?json=1
# https://geocode.xyz/3.5752,47.7945?json=1
# https://geocode.xyz/23.7118,37.9443?json=1
# https://geocode.xyz/112.8672,-6.9218?json=1
# https://geocode.xyz/0.8133,46.6473?json=1
# https://geocode.xyz/16.3042,57.9936?json=1
# https://geocode.xyz/25.9111,49.1038?json=1
# https://geocode.xyz/117.4301,23.7013?json=1
# https://geocode.xyz/-39.0711,-11.2568?json=1
# https://geocode.xyz/19.8833,40.9167?json=1
# https://geocode.xyz/106.6173,-6.2956?json=1
# https://geocode.xyz/20.2540,50.7481?json=1
# https://geocode.xyz/15.5597,46.0733?json=1
# https://geocode.xyz/110.6750,-7.6535?json=1
# https://geocode.xyz/29.2916,-26.2155?json=1
# https://geocode.xyz/3.2189,43.3363?json=1
# https://geocode.xyz/39.5314,44.4187?json=1
# https://geocode.xyz/-106.4170,31.9755?json=1
# https://geocode.xyz/168.0177,-46.3479?json=1
# https://geocode.xyz/-68.1038,-38.9615?json=1
# https://geocode.xyz/14.5216,59.3216?json=1
# https://geocode.xyz/-50.4537,-21.2029?json=1
# https://geocode.xyz/5.8978,43.4946?json=1
# https://geocode.xyz/-9.4852,52.4461?json=1
# https://geocode.xyz/111.7018,-8.2702?json=1
# https://geocode.xyz/44.4365,-12.1585?json=1
# https://geocode.xyz/106.8809,-6.4933?json=1
# https://geocode.xyz/-75.6499,4.8272?json=1
# https://geocode.xyz/-47.1322,-23.5257?json=1
# https://geocode.xyz/21.9542,51.3180?json=1
# https://geocode.xyz/113.0161,29.3944?json=1
# https://geocode.xyz/17.4884,52.9917?json=1
# https://geocode.xyz/26.0237,-24.4279?json=1
# https://geocode.xyz/26.7064,-30.6866?json=1
# https://geocode.xyz/22.0050,56.6745?json=1
# https://geocode.xyz/-8.3350,51.8610?json=1
# https://geocode.xyz/112.4909,-6.9842?json=1
# https://geocode.xyz/-49.3247,-16.1157?json=1
# https://geocode.xyz/110.9733,30.8231?json=1
# https://geocode.xyz/117.6099,34.4291?json=1
# https://geocode.xyz/25.8731,-24.6131?json=1
# https://geocode.xyz/107.3223,25.8223?json=1
# https://geocode.xyz/32.2633,55.8502?json=1
# https://geocode.xyz/141.7367,45.2029?json=1
# https://geocode.xyz/39.4129,51.6263?json=1
# https://geocode.xyz/115.1832,-8.6186?json=1
# https://geocode.xyz/112.5283,32.9907?json=1
# https://geocode.xyz/95.3081,32.5968?json=1
# https://geocode.xyz/108.4068,-7.0795?json=1
# https://geocode.xyz/17.4368,62.5263?json=1
# https://geocode.xyz/-86.3503,15.5847?json=1
# https://geocode.xyz/58.4687,35.2434?json=1
# https://geocode.xyz/23.2417,58.9920?json=1
# https://geocode.xyz/19.3046,51.2228?json=1
# https://geocode.xyz/110.3255,-7.8748?json=1
# https://geocode.xyz/29.7410,46.5085?json=1
# https://geocode.xyz/8.8390,11.7942?json=1
# https://geocode.xyz/8.2719,50.0897?json=1
# https://geocode.xyz/-68.2385,3.8565?json=1
# https://geocode.xyz/106.7210,28.7399?json=1
# https://geocode.xyz/12.3257,58.3354?json=1
# https://geocode.xyz/72.3111,31.2634?json=1
# https://geocode.xyz/111.1384,-6.7837?json=1
# https://geocode.xyz/-47.2090,-23.0886?json=1
#        id first_name last_name                          email gender   age  \
# 0   27625    Leandra   Pabelik            lpabelik5f@yale.edu      F  63.0
# 5   27497     Gordie   Bodicum          gbodicum1v@apache.org      M  60.0
# 12  27548    Stanley  McCullen  smccullen3a@timesonline.co.uk      M  60.0
# 15  27619    Shelley   Skeemor       sskeemor59@princeton.edu      F  44.0
# 16  27442       Mort   Midford             mmidfordc@yale.edu      M  59.0
#
#     money         lon        lat       phone registration  inactive  \
# 0   55.18   18.284100  49.632552  0136319724   2019-04-16     False
# 5   47.26   13.978681  49.786243  0146943857   2017-04-29     False
# 12    NaN  119.141473  28.074649  0875503094   2017-06-05      True
